# %% [markdown]
# <a href="https://colab.research.google.com/github/LazizAbduhalimov/AIPROJECT/blob/main/(14)%D0%9A%D0%BB%D0%B0%D1%81%D1%81%D0%B8%D1%84%D0%B8%D0%BA%D0%B0%D1%86%D0%B8%D1%8F_%D0%B8%D0%BD%D1%84%D0%B0%D1%80%D0%BA%D1%82%D0%BE%D0%B2_%D0%BC%D0%B8%D0%BE%D0%BA%D0%B0%D1%80%D0%B4%D0%B0_%D0%BF%D1%80%D0%B8_%D0%BF%D0%BE%D0%BC%D0%BE%D1%89%D0%B8_%D0%BA%D0%BE%D0%BC%D0%BF%D1%8C%D1%8E%D1%82%D0%B5%D1%80%D0%BD%D0%BE%D0%B3%D0%BE_%D0%B7%D1%80%D0%B5%D0%BD%D0%B8%D1%8F_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **III Вариант**

# %%
from google.colab import drive # Для работы с файлами в Google Drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-1-802e1da440af> in <cell line: 2>()
#       1 from google.colab import drive # Для работы с файлами в Google Drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     135   )
#     136   if ephemeral:
# --> 137     _message.blocking_request(
#     138         'request_auth',
# ...

# %%
dataset_path = '/content/drive/MyDrive/ECG_Data_Base_Uzbekistan_2024'

# %%
import os

# %%
MI_front_side_bez_Q_image = len(os.listdir(os.path.join(dataset_path, "MI_front_side_bez_Q (IPBSbQ)")))
Norma_image = len(os.listdir(os.path.join(dataset_path, "Norma (N)")))
MI_back_s_Q_image = len(os.listdir(os.path.join(dataset_path, "MI_back_s_Q (IZSsQ)")))
Right_bundle_branch_block_image = len(os.listdir(os.path.join(dataset_path, "Right_bundle_branch_block (BPN)")))
MI_front_septum_bez_Q_image = len(os.listdir(os.path.join(dataset_path, "MI_front_septum_bez_Q (IPPbQ)")))
MI_back_bez_Q_image = len(os.listdir(os.path.join(dataset_path, "MI_back_bez_Q (IZSbQ)")))
MI_front_bez_Q_image = len(os.li stdir(os.path.join(dataset_path, "MI_front_bez_Q (IPbQ)")))
Left_bundle_branch_block_image = len(os.listdir(os.path.join(dataset_path, "Left_bundle_branch_block (BLN)")))
MI_front_septum_s_Q_image = len(os.listdir(os.path.join(dataset_path, "MI_front_septum_s_Q (IPPsQ)")))

# %%
print("MI_front_side_bez_Q (IPBSbQ):",MI_front_side_bez_Q_image)
print("Norma (N):",Norma_image)
print("MI_back_s_Q (IZSsQ):",MI_back_s_Q_image)
print("Right_bundle_branch_block (BPN):",Right_bundle_branch_block_image)
print("MI_front_septum_bez_Q (IPPbQ):",MI_front_septum_bez_Q_image)
print("MI_back_bez_Q (IZSbQ):",MI_back_bez_Q_image)
print("MI_front_bez_Q (IPbQ):",MI_front_bez_Q_image)
print("Left_bundle_branch_block (BLN):",Left_bundle_branch_block_image)
print("MI_front_septum_s_Q (IPPsQ):",MI_front_septum_s_Q_image)
# Out:
# MI_front_side_bez_Q (IPBSbQ): 135
# Norma (N): 576
# MI_back_s_Q (IZSsQ): 41
# Right_bundle_branch_block (BPN): 159
# MI_front_septum_bez_Q (IPPbQ): 53
# MI_back_bez_Q (IZSbQ): 74
# MI_front_bez_Q (IPbQ): 136
# Left_bundle_branch_block (BLN): 130
# MI_front_septum_s_Q (IPPsQ): 157

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
labels=["MI_front_side_bez_Q (IPBSbQ)", "Norma (N)", "MI_back_s_Q (IZSsQ)", "Right_bundle_branch_block (BPN)", "MI_front_septum_bez_Q (IPPbQ)", "MI_back_bez_Q (IZSbQ)", "MI_front_bez_Q (IPbQ)", "Left_bundle_branch_block (BLN)", "MI_front_septum_s_Q (IPPsQ)"]
counts=[MI_front_side_bez_Q_image, Norma_image, MI_back_s_Q_image, Right_bundle_branch_block_image, MI_front_septum_bez_Q_image, MI_back_bez_Q_image, MI_front_bez_Q_image, Left_bundle_branch_block_image, MI_front_septum_s_Q_image]

# %%
plt.figure(figsize=(15, 9))
sns.barplot(x=labels, y=counts)
plt.xlabel('Image Type')
plt.ylabel('Count')
plt.title('Distribution of Images in Different Categories')
plt.show()

# %%
import plotly.express as px

# %%
fig = px.bar(x=labels, y=counts)
fig.update_layout(
    xaxis_title='Image Type',
    yaxis_title='Count',
    title='Distribution of Images in Different Categories',
    width=800,
    height=500
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plt.figure(figsize=(10, 10))
sns.set_palette("Set3")
plt.pie(counts, labels=labels, autopct='%1.1f%%')
plt.title('Distribution of Images in Different Categories')
plt.show()

# %%
import plotly.graph_objects as go

# %%
#Interactive Visualization
fig = go.Figure(data=[go.Pie(labels=labels, values=counts, textinfo='percent', insidetextorientation='radial')])
fig.update_layout(
    title='Distribution of Images in Different Categories',
    width=800,
    height=500
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
MI_front_side_bez_Q_path = os.path.join(dataset_path, "MI_front_side_bez_Q (IPBSbQ)")
Norma_path = os.path.join(dataset_path, "Norma (N)")
MI_back_s_Q_path = os.path.join(dataset_path, "MI_back_s_Q (IZSsQ)")
Right_bundle_branch_block_path = os.path.join(dataset_path, "Right_bundle_branch_block (BPN)")
MI_front_septum_bez_Q_path = os.path.join(dataset_path, "MI_front_septum_bez_Q (IPPbQ)")
MI_back_bez_Q_path = os.path.join(dataset_path, "MI_back_bez_Q (IZSbQ)")
MI_front_bez_Q_path = os.path.join(dataset_path, "MI_front_bez_Q (IPbQ)")
Left_bundle_branch_block_path = os.path.join(dataset_path, "Left_bundle_branch_block (BLN)")
MI_front_septum_s_Q_path = os.path.join(dataset_path, "MI_front_septum_s_Q (IPPsQ)")

# %%
import cv2

# %%
MI_front_side_bez_Q_files = os.listdir(MI_front_side_bez_Q_path)
Norma_files = os.listdir(Norma_path)
MI_back_s_Q_files = os.listdir(MI_back_s_Q_path)
Right_bundle_branch_block_files = os.listdir(Right_bundle_branch_block_path)
MI_front_septum_bez_Q_files = os.listdir(MI_front_septum_bez_Q_path)
MI_back_bez_Qfiles = os.listdir(MI_back_bez_Q_path)
MI_front_bez_Q_files = os.listdir(MI_front_bez_Q_path)
Left_bundle_branch_block_files = os.listdir(Left_bundle_branch_block_path)
MI_front_septum_s_Q_files = os.listdir(MI_front_septum_s_Q_path)

# %%
def view_image(image_name,image_files,image_file_path):
    fig,axes=plt.subplots(3,3,figsize=(10,10))
    fig.suptitle(image_name,fontsize=16)
    axes=axes.ravel()

    for i,image_file in enumerate(image_files[:9]):
        image_path=os.path.join(image_file_path,image_file)
        image=cv2.imread(image_path)
        image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
        axes[i].imshow(image)
        axes[i].axis('off')

    plt.tight_layout()
    plt.show()

# %%
view_image("MI_front_side_bez_Q (IPBSbQ)",MI_front_side_bez_Q_files[2:13],MI_front_side_bez_Q_path)

# %%
# since it's image data, hence we have to ensure all images have same pixel size
# so resizing the image by 224*224
def load_and_preprocess_image(image_folder):
    image_files = os.listdir(image_folder)
    images = []

    for image_file in image_files :
        image_path = os.path.join(image_folder, image_file)
        image = cv2.imread(image_path)
        if image is not None:
            image = cv2.resize(image, (128,128))
            images.append(image)
    return images

# %%
MI_front_side_bez_Q_files = load_and_preprocess_image(MI_front_side_bez_Q_path)
Norma_files = load_and_preprocess_image(Norma_path)
MI_back_s_Q_files = load_and_preprocess_image(MI_back_s_Q_path)
Right_bundle_branch_block_files = load_and_preprocess_image(Right_bundle_branch_block_path)
MI_front_septum_bez_Q_files = load_and_preprocess_image(MI_front_septum_bez_Q_path)
MI_back_bez_Q_files = load_and_preprocess_image(MI_back_bez_Q_path)
MI_front_bez_Q_files = load_and_preprocess_image(MI_front_bez_Q_path)
Left_bundle_branch_block_files = load_and_preprocess_image(Left_bundle_branch_block_path)
MI_front_septum_s_Q_files = load_and_preprocess_image(MI_front_septum_s_Q_path)

# %%
import numpy as np

# %%
MI_front_side_bez_Q_files = np.array(MI_front_side_bez_Q_files).reshape(-1, 128, 128, 3)
Norma_files = np.array(Norma_files).reshape(-1, 128, 128, 3)
MI_back_s_Q_files = np.array(MI_back_s_Q_files).reshape(-1, 128, 128, 3)
Right_bundle_branch_block_files = np.array(Right_bundle_branch_block_files).reshape(-1, 128, 128, 3)
MI_front_septum_bez_Q_files = np.array(MI_front_septum_bez_Q_files).reshape(-1, 128, 128, 3)
MI_back_bez_Q_files = np.array(MI_back_bez_Q_files).reshape(-1, 128, 128, 3)
MI_front_bez_Q_files = np.array(MI_front_bez_Q_files).reshape(-1, 128, 128, 3)
Left_bundle_branch_block_files = np.array(Left_bundle_branch_block_files).reshape(-1, 128, 128, 3)
MI_front_septum_s_Q_files = np.array(MI_front_septum_s_Q_files).reshape(-1, 128, 128, 3)

# %%
all_files = np.concatenate((MI_front_side_bez_Q_files, Norma_files, MI_back_s_Q_files, Right_bundle_branch_block_files, MI_front_septum_bez_Q_files, MI_back_bez_Q_files, MI_front_bez_Q_files, Left_bundle_branch_block_files, MI_front_septum_s_Q_files), axis=0)

all_labels = np.concatenate((
np.zeros(len(MI_front_side_bez_Q_files)),
np.ones(len(Norma_files)),
np.ones(len(MI_back_s_Q_files)) * 2,
np.ones(len(Right_bundle_branch_block_files)) * 3,
np.ones(len(MI_front_septum_bez_Q_files))*4,
np.ones(len(MI_back_bez_Q_files)) * 5,
np.ones(len(MI_front_bez_Q_files)) * 6,
np.ones(len(Left_bundle_branch_block_files))*7,
np.ones(len(MI_front_septum_s_Q_files))*8
))

# %%
#converting 4D array into 2-D array using ndarray.reshape(-1,Height,Width,Color Channels)
all_files_flaten=all_files.reshape(-1,all_files.shape[1]*all_files.shape[2]*all_files.shape[3])

# %%
from imblearn.over_sampling import RandomOverSampler
from imblearn.over_sampling import SMOTE

# %%
ros = RandomOverSampler(random_state=42)
all_files_flat_resampled, all_labels_resampled = ros.fit_resample(all_files_flaten, all_labels)

# %%
ros = SMOTE(random_state=42)
all_files_flat_resampled, all_labels_resampled = ros.fit_resample(all_files_flaten, all_labels)

# %%
unique_resampled, counts_resampled = np.unique(all_labels_resampled, return_counts=True)
class_counts_resampled = dict(zip(unique_resampled, counts_resampled))

print("New class distribution after resampling:", class_counts_resampled)
# Out:
# New class distribution after resampling: {0.0: 576, 1.0: 576, 2.0: 576, 3.0: 576, 4.0: 576, 5.0: 576, 6.0: 576, 7.0: 576, 8.0: 576}

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix

# %%
X_train, X_test, y_train, y_test = train_test_split(all_files_flat_resampled, all_labels_resampled, test_size=0.2, stratify=all_labels_resampled,
                                                    random_state=42)

# %%
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[236, 252, 254, ..., 230, 246, 224],
#        [236, 252, 254, ..., 231, 246, 223],
#        [230, 253, 252, ..., 145, 163, 254],
#        ...,
#        [230, 253, 252, ..., 234, 253, 255],
#        [236, 252, 254, ..., 232, 246, 224],
#        [245, 253, 252, ..., 234, 253, 255]], dtype=uint8)

# %%
X_train_scaled
# Out:
# array([[0.9254902 , 0.98809524, 0.99603175, ..., 0.90196078, 0.96442688,
#         0.87843137],
#        [0.9254902 , 0.98809524, 0.99603175, ..., 0.90588235, 0.96442688,
#         0.8745098 ],
#        [0.90196078, 0.99206349, 0.98809524, ..., 0.56862745, 0.63636364,
#         0.99607843],
#        ...,
#        [0.90196078, 0.99206349, 0.98809524, ..., 0.91764706, 0.99209486,
#         1.        ],
#        [0.9254902 , 0.98809524, 0.99603175, ..., 0.90980392, 0.96442688,
#         0.87843137],
#        [0.96078431, 0.99206349, 0.98809524, ..., 0.91764706, 0.99209486,
#         1.        ]])

# %%
X_test
# Out:
# array([[236, 252, 254, ..., 234,  31, 253],
#        [230, 253, 252, ..., 234, 253, 255],
#        [236, 252, 254, ..., 204, 246, 223],
#        ...,
#        [236, 252, 254, ..., 230, 246, 224],
#        [236, 252, 254, ..., 231, 246, 223],
#        [236, 252, 254, ..., 230, 246, 224]], dtype=uint8)

# %%
X_test_scaled
# Out:
# array([[0.9254902 , 0.98809524, 0.99603175, ..., 0.91764706, 0.11462451,
#         0.99215686],
#        [0.90196078, 0.99206349, 0.98809524, ..., 0.91764706, 0.99209486,
#         1.        ],
#        [0.9254902 , 0.98809524, 0.99603175, ..., 0.8       , 0.96442688,
#         0.8745098 ],
#        ...,
#        [0.9254902 , 0.98809524, 0.99603175, ..., 0.90196078, 0.96442688,
#         0.87843137],
#        [0.9254902 , 0.98809524, 0.99603175, ..., 0.90588235, 0.96442688,
#         0.8745098 ],
#        [0.9254902 , 0.98809524, 0.99603175, ..., 0.90196078, 0.96442688,
#         0.87843137]])

# %%
# svm_classifier = SVC(random_state=42)

# %%
# svm_classifier.fit(X_train_scaled, y_train)

# %%
# svm_predictions = svm_classifier.predict(X_test_scaled)

# %%
# accuracy = accuracy_score(y_test, svm_predictions)
# print("Accuracy:", accuracy)

# precision = precision_score(y_test, svm_predictions, average=None)
# recall = recall_score(y_test, svm_predictions, average=None)
# f1 = f1_score(y_test, svm_predictions, average=None)

# for class_label, prec, rec, f1_score in zip(["Class 0", "Class 1", "Class 2", "Class 3", "Class 4", "Class 5", "Class 6", "Class 7", "Class 8"], precision, recall, f1):
#     print(f"Class {class_label}:")
#     print(f"  Precision: {prec:.4f}")
#     print(f"  Recall: {rec:.4f}")
#     print(f"  F1-score: {f1_score:.4f}\n")

# report = classification_report(y_test, svm_predictions)
# print("Classification Report:\n", report)

# confusion = confusion_matrix(y_test, svm_predictions)
# print("Confusion Matrix:\n", confusion)

# %% [markdown]
# Давайте определим термины, используемые в отчете о классификации:
#
# **Аккуратность (Accuracy):**
#
# Определение: Отношение правильно предсказанных экземпляров к общему числу экземпляров.
#
# Формула: (\frac{\text{Количество правильных предсказаний}}{\text{Общее количество предсказаний}})
#
# **Точность (Precision):**
#
# Определение: Отношение правильно предсказанных положительных наблюдений к общему числу предсказанных положительных.
#
# Формула: (\frac{\text{Истинные положительные}}{\text{Истинные положительные + Ложные положительные}})
#
# Интерпретация: Точность фокусируется на точности положительных предсказаний.
#
# **Полнота (Recall)** (Чувствительность или Истинная положительная доля):
#
# Определение: Отношение правильно предсказанных положительных наблюдений ко всем наблюдениям в фактическом классе.
#
# Формула: (\frac{\text{Истинные положительные}}{\text{Истинные положительные + Ложные отрицательные}})
#
# Интерпретация: Полнота фокусируется на охвате положительных экземпляров.
#
# **F1 мера (F1 Score):**
#
# Определение: Взвешенное среднее точности и полноты. Это баланс между точностью и полнотой.
#
# Формула: (2 \times \frac{\text{Точность} \times \text{Полнота}}{\text{Точность + Полнота}})
#
# Интерпретация: F1 мера учитывает как ложные положительные, так и ложные отрицательные.
#
# **Макро-среднее (Macro Avg):**
#
# Определение: Средняя точность, полнота или F1 мера по всем классам, без учета дисбаланса классов.
#
# Формула: Суммирование индивидуальных оценок классов и деление на количество классов.
#
# **Взвешенное среднее (Weighted Avg):**
#
# Определение: Средняя точность, полнота или F1 мера по всем классам с учетом дисбаланса классов.
#
# Формула: Суммирование произведения каждой оценки класса и доли класса в наборе данных.
#
# Эти метрики помогают оценить производительность модели классификации, учитывая различные аспекты, такие как общая корректность, точность, полнота и их баланс.

# %%
# !pip install scikit-plot

# %%
import scikitplot as skplt

# %%
# skplt.metrics.plot_confusion_matrix(y_test, svm_predictions, normalize=True)
# plt.show()

# %%
# rf_classifier = RandomForestClassifier(n_estimators=10,random_state=42)

# %%
# rf_classifier.fit(X_train_scaled, y_train)

# %%
# rf_predictions = rf_classifier.predict(X_test_scaled)

# %%
# accuracy = accuracy_score(y_test, rf_predictions)
# print("Accuracy:", accuracy)

# report = classification_report(y_test, rf_predictions)
# print("Classification Report:\n", report)

# confusion = confusion_matrix(y_test, rf_predictions)
# print("Confusion Matrix:\n", confusion)

# %%
# skplt.metrics.plot_confusion_matrix(y_test, rf_predictions, normalize=True)
# plt.show()

# %%
# from sklearn.tree import DecisionTreeClassifier

# %%
# dt_classifier = DecisionTreeClassifier(random_state=42)

# %%
# dt_classifier.fit(X_train_scaled, y_train)

# %%
# dt_predictions = dt_classifier.predict(X_test_scaled)

# %%
# accuracy = accuracy_score(y_test, dt_predictions)
# print("Accuracy:", accuracy)

# report = classification_report(y_test, dt_predictions)
# print("Classification Report:\n", report)

# confusion = confusion_matrix(y_test, dt_predictions)
# print("Confusion Matrix:\n", confusion)

# %%
# skplt.metrics.plot_confusion_matrix(y_test, dt_predictions, normalize=True)
# plt.show()

# %%
# plt.figure(figsize=(8, 6))
# classifiers = ['Support Vector Machine', 'Random Forest', 'Decision Tree']
# accuracies = [0.7733847637415622, 0.7888138862102217, 0.656702025072324]
# plt.bar(classifiers, accuracies, color=['blue', 'green', 'red'])
# plt.xlabel('Classifier')
# plt.ylabel('Accuracy')
# plt.title('Accuracy Comparison - Support Vector Machine vs. Random Forest vs. Decision Tree')
# plt.ylim(0, 1)
# plt.show()

# %%
# fig = px.bar(x=classifiers, y=accuracies, color=classifiers,
#              labels={'x': 'Classifier', 'y': 'Accuracy'},
#              title='Accuracy Comparison - Support Vector Machine vs. Random Forest vs. Decision Tree')
# fig.show()

# %% [markdown]
# **Глубокое обучение**

# %%
import tensorflow as tf
tf.keras.backend.clear_session()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam

# %%
X_train_scaled.shape
# Out:
# (4147, 49152)

# %%
y_train.shape
# Out:
# (4147,)

# %%
# model = Sequential([
#     Flatten(input_shape=(128, 128, 3)),
#     Dense(128, activation='relu'),
#     Dropout(0.25),
#     Dense(64, activation='relu'),
#     Dense(9, activation='softmax')
# ])

# %%
# model.compile(optimizer=Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
X_train_scaled_new = X_train_scaled.reshape(-1, 128, 128, 3)

# %%
# history = model.fit(X_train_scaled_new, y_train, epochs=10, batch_size=32, validation_split=0.2)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.activations import swish

# %%
model = Sequential()

# %%
model.add(Conv2D(32, (3, 3), activation=swish, input_shape=(128, 128, 3)))
model.add(MaxPooling2D(pool_size=(2, 2)))


model.add(Conv2D(64, (3, 3), activation=swish))
model.add(MaxPooling2D(pool_size=(2, 2)))


model.add(Conv2D(128, (3, 3), activation=swish))
model.add(MaxPooling2D(pool_size=(2, 2)))


model.add(Flatten())


model.add(Dense(512, activation=swish))
model.add(Dropout(0.5))


model.add(Dense(256, activation=swish))
model.add(Dropout(0.5))

model.add(Dense(128, activation=swish))
model.add(Dropout(0.5))


model.add(Dense(9, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 126, 126, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 63, 63, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 61, 61, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 30, 30, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 128)       73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 14, 14, 128)       0
#  g2D)
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 512)               12845568
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dropout_2 (Dropout)         (None, 128)               0
#
# ...

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(X_train_scaled_new, y_train, epochs=20, batch_size= 50 , validation_split=0.2)
# Out:
# Epoch 1/20
# 67/67 [==============================] - 5s 54ms/step - loss: 0.0492 - accuracy: 0.9798 - val_loss: 1.2962 - val_accuracy: 0.8819
# Epoch 2/20
# 67/67 [==============================] - 3s 47ms/step - loss: 0.0429 - accuracy: 0.9816 - val_loss: 1.2774 - val_accuracy: 0.8687
# Epoch 3/20
# 67/67 [==============================] - 3s 47ms/step - loss: 0.0611 - accuracy: 0.9777 - val_loss: 1.2959 - val_accuracy: 0.8699
# Epoch 4/20
# 67/67 [==============================] - 3s 48ms/step - loss: 0.0410 - accuracy: 0.9828 - val_loss: 1.3305 - val_accuracy: 0.8783
# Epoch 5/20
# 67/67 [==============================] - 3s 46ms/step - loss: 0.0405 - accuracy: 0.9816 - val_loss: 1.3294 - val_accuracy: 0.8687
# Epoch 6/20
# 67/67 [==============================] - 3s 46ms/step - loss: 0.0645 - accuracy: 0.9762 - val_loss: 1.2088 - val_accuracy: 0.8687
# Epoch 7/20
# ...

# %%
X_test_scaled_new = X_test_scaled.reshape(-1, 128, 128, 3)

# %%
predictions = model.predict(X_test_scaled_new)
# Out:
# 33/33 [==============================] - 0s 10ms/step

# %%
predicted_labels = predictions.argmax(axis=1)

# %%
accuracy = accuracy_score(y_test, predicted_labels)
conf_matrix = confusion_matrix(y_test, predicted_labels)
class_report = classification_report(y_test, predicted_labels)

print(f"Accuracy: {accuracy:.2f}")
print("Confusion Matrix:")
print(conf_matrix)
print("Classification Report:")
print(class_report)
# Out:
# Accuracy: 0.88
# Confusion Matrix:
# [[ 96   1   2   2   1   4   3   5   1]
#  [  1 105   0   0   0   2   2   1   4]
#  [  0   1 107   1   1   0   4   1   0]
#  [  1   1   1 110   3   0   0   0   0]
#  [  0   1   2   0 107   0   1   0   4]
#  [  1   6   0   1   0 101   6   0   0]
#  [  6   2   1   3   1   6  93   0   4]
#  [  2   0   0   0   1   1   3 107   1]
#  [  4   2   0   2   3   1  13   1  89]]
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.83      0.85       115
#          1.0       0.88      0.91      0.90       115
#          2.0       0.95      0.93      0.94       115
#          3.0       0.92      0.95      0.94       116
#          4.0       0.91      0.93      0.92       115
#          5.0       0.88      0.88      0.88       115
#          6.0       0.74      0.80      0.77       116
#          7.0       0.93      0.93      0.93       115
#          8.0       0.86      0.77      0.82       115
#
# ...

# %%
skplt.metrics.plot_confusion_matrix(y_test, predicted_labels, normalize=True)
plt.show()

# %%
plt.plot(history.history['accuracy'], color='blue')
plt.plot(history.history['val_accuracy'], color='green')
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'], color='blue')
plt.plot(history.history['val_loss'], color='green')
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# **Сохранение модели и проверка ее работы**

# %%
model.save('ECGSemashko.model')

# %%
from keras.models import load_model

model = load_model('ECGSemashko.model')

# %%
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

# Loading the test image
img_path = '/content/drive/MyDrive/ECG_Data_Base_Uzbekistan_2024/MI_front_septum_bez_Q (IPPbQ)/IPPbQ (13).jpg'
import matplotlib.image as mpimg

img = mpimg.imread(img_path)

# Display the image
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
img = image.load_img(img_path, target_size=(128, 128))
img_array= np.array(img).reshape(-1, 128, 128, 3)

# %%
predictions = model.predict(img_array)
# Out:
# 1/1 [==============================] - 0s 19ms/step

# %%
predicted_class_index = np.argmax(predictions)
confidence = predictions[0, predicted_class_index]

print("Predicted class index:", predicted_class_index)
print("Confidence:", confidence)
# Out:
# Predicted class index: 4
# Confidence: 1.0
